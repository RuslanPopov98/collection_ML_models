# %%
import pandas as pd

# %%
pd.options.display.max_rows = 100

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train = train.drop(['Id'], axis=1)

# %%
#train

# %%
def features_have_nans(data):
# Out:
#   File "<ipython-input-13-c1728c95ade9>", line 1
#     def check_nans(data):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
#train.isnull().any()
#train.isnull().sum()

# %%
columns_with_nans = pd.DataFrame(train.isnull().any(), columns = ['isnan'])
nan_cols = list(columns_with_nans[columns_with_nans.isnan == True].index)

# %%
train[nan_cols].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# #### Дропнули одну строку с Nan в столбце Electrical

# %%
train = train.dropna(subset=['Electrical'])

# %%
#nan_cols_temp = ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageFinish', 
#                 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

nans_NA = ['MiscFeature', 'Fence', 'PoolQC', 'GarageCond', 'GarageFinish', 'GarageType', 'FireplaceQu', 'BsmtFinType2', 
           'BsmtFinType1', 'BsmtQual','BsmtCond','BsmtExposure','Alley']

def print_unique_value(data, feat_list, categ = True):
    for feat in feat_list:
        print(feat, train[feat].unique())

print_unique_value(train, nan_cols_temp)
# Out:
# Alley [nan 'Grvl' 'Pave']
# MasVnrType ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
# BsmtQual ['Gd' 'TA' 'Ex' nan 'Fa']
# BsmtCond ['TA' 'Gd' nan 'Fa' 'Po']
# BsmtExposure ['No' 'Gd' 'Mn' 'Av' nan]
# BsmtFinType1 ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# BsmtFinType2 ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Electrical ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# FireplaceQu [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# GarageType ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageFinish ['RFn' 'Unf' 'Fin' nan]
# GarageQual ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# GarageCond ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
# PoolQC [nan 'Ex' 'Fa' 'Gd']
# Fence [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# MiscFeature [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %%
train[nans_NA].isnull().sum()
# Out:
# MiscFeature     1405
# Fence           1178
# PoolQC          1452
# GarageCond        81
# GarageFinish      81
# GarageType        81
# FireplaceQu      689
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# Alley           1368
# dtype: int64

# %%
train[nans_NA].fillna(value='N')
# Out:
#      MiscFeature  Fence PoolQC GarageCond GarageFinish GarageType FireplaceQu  \
# 0              N      N      N         TA          RFn     Attchd           N
# 1              N      N      N         TA          RFn     Attchd          TA
# 2              N      N      N         TA          RFn     Attchd          TA
# 3              N      N      N         TA          Unf     Detchd          Gd
# 4              N      N      N         TA          RFn     Attchd          TA
# ...          ...    ...    ...        ...          ...        ...         ...
# 1455           N      N      N         TA          RFn     Attchd          TA
# 1456           N  MnPrv      N         TA          Unf     Attchd          TA
# 1457        Shed  GdPrv      N         TA          RFn     Attchd          Gd
# 1458           N      N      N         TA          Unf     Attchd           N
# 1459           N      N      N         TA          Fin     Attchd           N
#
# ...

# %%
train[nans_NA].isnull().sum()
# Out:
# MiscFeature     1405
# Fence           1178
# PoolQC          1452
# GarageCond        81
# GarageFinish      81
# GarageType        81
# FireplaceQu      689
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# Alley           1368
# dtype: int64

# %%
train['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
train['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
train['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
train.BsmtQual.value_counts(dropna=False)
# Out:
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
